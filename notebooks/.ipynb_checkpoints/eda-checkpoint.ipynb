# %% [markdown]
# ## Eksplorasi Data Transaksi

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import googlemaps

import numpy as np

import requests

import openpyxl

import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# #### Load Data

# %%
# Load the Excel file into a pandas DataFrame
df = pd.read_excel('../data/df_distance.xlsx')
df.head()
# Out:
#    id       id_telp                    email   tanggal jenis_pesanan  \
# 0   1  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
# 1   2  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
# 2   3  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
# 3   4  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Food
# 4   5  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
#
#         datetime_tugas                                      lokasi_jemput  \
# 0  2023-05-01 14:01:00             Jl. Cigadung Raya Barat No.6, Cigadung
# 1  2023-05-01 12:16:00               Jl. Sukamulya, Kopo, Bojongloa Kaler
# 2  2023-05-01 11:50:00                Jl. Jendral Ahmad Yani Kiaracondong
# 3  2023-05-01 11:35:00  Gg. Irit No.14, Pasirlayung, Kec. Cibeunying K...
# 4  2023-05-01 10:51:00  Jl. Cikutra No.167, Neglasari, Kec. Cibeunying...
#
#    lat_jemput  long_jemput                                      lokasi_tujuan  \
# 0   -6.871760   107.620055                  Rancakalong RT/RW 04/04, Cigadung
# 1   -6.936636   107.585652                 Jl. Cibogo Atas No. 148, Sukawarna
# 2   -6.904833   107.647971                196b, Gg. Pabrik Kulit Selatan No.2
# 3   -6.901228   107.656385  Jl. Padasuka No.20, Pasirlayung, Kec. Cibeunyi...
# 4   -6.896515   107.643428  Jl. Cihampelas No.159, Cipaganti, Kecamatan Co...
#
#    lat_tujuan  long_tujuan     datetime_selesai  jarak pendapatan_bersih  \
# 0   -6.822729   107.844186  2023-05-01 14:11:00   1.67              8000
# 1   -6.882776   107.575037  2023-05-01 12:49:00   9.03             18400
# 2   -6.939039   107.589858  2023-05-01 12:15:00   9.55             19200
# 3   -6.901107   107.653824  2023-05-01 11:48:00   0.37              7200
# 4   -6.893258   107.603637  2023-05-01 11:16:00   7.62             15600
#
#    poin_tambahan jenis_pembayaran  jarak_jemput_tujuan
# 0          150.0           Dompet               70.216
# 1          150.0            Tunai               18.526
# 2          150.0            Tunai                9.526
# 3          150.0            Tunai                0.339
# 4          150.0            Tunai                6.584

# %% [markdown]
# #### Data Cleaning Distance

# %% [markdown]
# Cek apakah fload atau bukan -> pisahkan

# %%
# Fungsi untuk memeriksa apakah nilai dapat diubah menjadi float atau tidak
def is_float(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

# Memeriksa kolom jarak_transaksi
invalid_jarak_transaksi = df[~df['jarak'].apply(is_float)]

# Memeriksa kolom jarak_google_maps
invalid_jarak_google_maps = df[~df['jarak_jemput_tujuan'].apply(is_float)]

# %%
invalid_jarak_transaksi
# Out:
# Empty DataFrame
# Columns: [id, id_telp, email, tanggal, jenis_pesanan, datetime_tugas, lokasi_jemput, lat_jemput, long_jemput, lokasi_tujuan, lat_tujuan, long_tujuan, datetime_selesai, jarak, pendapatan_bersih, poin_tambahan, jenis_pembayaran, jarak_jemput_tujuan]
# Index: []

# %%
invalid_jarak_google_maps
# Out:
# Empty DataFrame
# Columns: [id, id_telp, email, tanggal, jenis_pesanan, datetime_tugas, lokasi_jemput, lat_jemput, long_jemput, lokasi_tujuan, lat_tujuan, long_tujuan, datetime_selesai, jarak, pendapatan_bersih, poin_tambahan, jenis_pembayaran, jarak_jemput_tujuan]
# Index: []

# %% [markdown]
# Convert menjadi float

# %%
# convert kolom-kolom jarak menjadi float
df['jarak'] = df['jarak'].astype(float)
df['jarak_jemput_tujuan'] = df['jarak_jemput_tujuan'].astype(float)

# %%
df['jarak'].describe()
# Out:
# count    28947.000000
# mean         3.784628
# std          3.193548
# min          0.000000
# 25%          1.670000
# 50%          2.880000
# 75%          4.870000
# max         45.450000
# Name: jarak, dtype: float64

# %% [markdown]
# #### Hitung perbedaan antara jarak asli dan jarak hasil geocoding dan distance matrix

# %%
# Menghitung Perbedaan Jarak
df['perbedaan_jarak'] = abs(df['jarak'] - df['jarak_jemput_tujuan'])
df.head()
# Out:
#    id       id_telp                    email   tanggal jenis_pesanan  \
# 0   1  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
# 1   2  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
# 2   3  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
# 3   4  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Food
# 4   5  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
#
#         datetime_tugas                                      lokasi_jemput  \
# 0  2023-05-01 14:01:00             Jl. Cigadung Raya Barat No.6, Cigadung
# 1  2023-05-01 12:16:00               Jl. Sukamulya, Kopo, Bojongloa Kaler
# 2  2023-05-01 11:50:00                Jl. Jendral Ahmad Yani Kiaracondong
# 3  2023-05-01 11:35:00  Gg. Irit No.14, Pasirlayung, Kec. Cibeunying K...
# 4  2023-05-01 10:51:00  Jl. Cikutra No.167, Neglasari, Kec. Cibeunying...
#
#    lat_jemput  long_jemput                                      lokasi_tujuan  \
# 0   -6.871760   107.620055                  Rancakalong RT/RW 04/04, Cigadung
# 1   -6.936636   107.585652                 Jl. Cibogo Atas No. 148, Sukawarna
# 2   -6.904833   107.647971                196b, Gg. Pabrik Kulit Selatan No.2
# 3   -6.901228   107.656385  Jl. Padasuka No.20, Pasirlayung, Kec. Cibeunyi...
# 4   -6.896515   107.643428  Jl. Cihampelas No.159, Cipaganti, Kecamatan Co...
#
#    lat_tujuan  long_tujuan     datetime_selesai  jarak pendapatan_bersih  \
# 0   -6.822729   107.844186  2023-05-01 14:11:00   1.67              8000
# 1   -6.882776   107.575037  2023-05-01 12:49:00   9.03             18400
# 2   -6.939039   107.589858  2023-05-01 12:15:00   9.55             19200
# 3   -6.901107   107.653824  2023-05-01 11:48:00   0.37              7200
# 4   -6.893258   107.603637  2023-05-01 11:16:00   7.62             15600
#
#    poin_tambahan jenis_pembayaran  jarak_jemput_tujuan  perbedaan_jarak
# 0          150.0           Dompet               70.216           68.546
# 1          150.0            Tunai               18.526            9.496
# 2          150.0            Tunai                9.526            0.024
# 3          150.0            Tunai                0.339            0.031
# 4          150.0            Tunai                6.584            1.036

# %%
correct = df[df['perbedaan_jarak']<5]
correct.shape
# Out:
# (27437, 19)

# %%
correct.head()
# Out:
#    id       id_telp                    email   tanggal jenis_pesanan  \
# 2   3  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
# 3   4  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Food
# 4   5  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
# 5   6  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
# 6   7  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
#
#         datetime_tugas                                      lokasi_jemput  \
# 2  2023-05-01 11:50:00                Jl. Jendral Ahmad Yani Kiaracondong
# 3  2023-05-01 11:35:00  Gg. Irit No.14, Pasirlayung, Kec. Cibeunying K...
# 4  2023-05-01 10:51:00  Jl. Cikutra No.167, Neglasari, Kec. Cibeunying...
# 5  2023-05-01 10:14:00  Jl. Gegerkalong Hilir No.8, RW.01, Gegerkalong...
# 6  2023-05-01 09:05:00  Cicaheum, Kec. Kiaracondong, Kota Bandung, Jaw...
#
#    lat_jemput  long_jemput                                      lokasi_tujuan  \
# 2   -6.904833   107.647971                196b, Gg. Pabrik Kulit Selatan No.2
# 3   -6.901228   107.656385  Jl. Padasuka No.20, Pasirlayung, Kec. Cibeunyi...
# 4   -6.896515   107.643428  Jl. Cihampelas No.159, Cipaganti, Kecamatan Co...
# 5   -6.870245   107.593153  Jl. Jiwanaya No.02, RT.01/RW.04, Cibeunying, K...
# 6   -6.903948   107.652282  Jl. Puri Dago Mas Utara 1 No.33, Antapani Teng...
#
#    lat_tujuan  long_tujuan     datetime_selesai  jarak pendapatan_bersih  \
# 2   -6.939039   107.589858  2023-05-01 12:15:00   9.55             19200
# 3   -6.901107   107.653824  2023-05-01 11:48:00   0.37              7200
# 4   -6.893258   107.603637  2023-05-01 11:16:00   7.62             15600
# 5   -6.879492   107.631440  2023-05-01 10:39:00   7.80             16000
# 6   -6.922764   107.665858  2023-05-01 09:17:00   3.90              8000
#
#    poin_tambahan jenis_pembayaran  jarak_jemput_tujuan  perbedaan_jarak
# 2          150.0            Tunai                9.526            0.024
# 3          150.0            Tunai                0.339            0.031
# 4          150.0            Tunai                6.584            1.036
# 5          150.0           Dompet                8.390            0.590
# 6          150.0           Dompet                3.817            0.083

# %%
# Load the Excel file into a pandas DataFrame
check = pd.read_excel('../data/after_check.xlsx')
check.shape
# Out:
# /home/peminumyakult/anaconda3/envs/suapp/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# (46, 19)

# %%
final_df = pd.concat([correct, check], ignore_index=True)
final_df.shape

# %%
final_df.to_excel('../data/final_df.xlsx', index=False)

# %% [markdown]
# #### Load final_df

# %%
# Load the Excel file into a pandas DataFrame
final_df = pd.read_excel('../data/final_df.xlsx')
final_df.head()
# Out:
#    id       id_telp                    email   tanggal jenis_pesanan  \
# 0   3  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
# 1   4  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Food
# 2   5  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
# 3   6  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
# 4   7  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
#
#         datetime_tugas                                      lokasi_jemput  \
# 0  2023-05-01 11:50:00                Jl. Jendral Ahmad Yani Kiaracondong
# 1  2023-05-01 11:35:00  Gg. Irit No.14, Pasirlayung, Kec. Cibeunying K...
# 2  2023-05-01 10:51:00  Jl. Cikutra No.167, Neglasari, Kec. Cibeunying...
# 3  2023-05-01 10:14:00  Jl. Gegerkalong Hilir No.8, RW.01, Gegerkalong...
# 4  2023-05-01 09:05:00  Cicaheum, Kec. Kiaracondong, Kota Bandung, Jaw...
#
#    lat_jemput  long_jemput                                      lokasi_tujuan  \
# 0   -6.904833   107.647971                196b, Gg. Pabrik Kulit Selatan No.2
# 1   -6.901228   107.656385  Jl. Padasuka No.20, Pasirlayung, Kec. Cibeunyi...
# 2   -6.896515   107.643428  Jl. Cihampelas No.159, Cipaganti, Kecamatan Co...
# 3   -6.870245   107.593153  Jl. Jiwanaya No.02, RT.01/RW.04, Cibeunying, K...
# 4   -6.903948   107.652282  Jl. Puri Dago Mas Utara 1 No.33, Antapani Teng...
#
#    lat_tujuan  long_tujuan     datetime_selesai  jarak pendapatan_bersih  \
# 0   -6.939039   107.589858  2023-05-01 12:15:00   9.55             19200
# 1   -6.901107   107.653824  2023-05-01 11:48:00   0.37              7200
# 2   -6.893258   107.603637  2023-05-01 11:16:00   7.62             15600
# 3   -6.879492   107.631440  2023-05-01 10:39:00   7.80             16000
# 4   -6.922764   107.665858  2023-05-01 09:17:00   3.90              8000
#
#    poin_tambahan jenis_pembayaran  jarak_jemput_tujuan  perbedaan_jarak
# 0          150.0            Tunai                9.526            0.024
# 1          150.0            Tunai                0.339            0.031
# 2          150.0            Tunai                6.584            1.036
# 3          150.0           Dompet                8.390            0.590
# 4          150.0           Dompet                3.817            0.083

# %%
final_df[final_df.duplicated(subset=['id'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [id, id_telp, email, tanggal, jenis_pesanan, datetime_tugas, lokasi_jemput, lat_jemput, long_jemput, lokasi_tujuan, lat_tujuan, long_tujuan, datetime_selesai, jarak, pendapatan_bersih, poin_tambahan, jenis_pembayaran, jarak_jemput_tujuan, perbedaan_jarak]
# Index: []

# %%
final_df.shape
# Out:
# (27483, 19)

# %%
under_1km = final_df[final_df['perbedaan_jarak']<1]
under_1km.head()
# Out:
#    id       id_telp                    email   tanggal jenis_pesanan  \
# 0   3  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
# 1   4  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Food
# 3   6  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
# 4   7  8.212093e+10  brigezwawan72@gmail.com  5/1/2023          Ride
# 5   8  8.212093e+10  brigezwawan72@gmail.com  5/2/2023          Food
#
#         datetime_tugas                                      lokasi_jemput  \
# 0  2023-05-01 11:50:00                Jl. Jendral Ahmad Yani Kiaracondong
# 1  2023-05-01 11:35:00  Gg. Irit No.14, Pasirlayung, Kec. Cibeunying K...
# 3  2023-05-01 10:14:00  Jl. Gegerkalong Hilir No.8, RW.01, Gegerkalong...
# 4  2023-05-01 09:05:00  Cicaheum, Kec. Kiaracondong, Kota Bandung, Jaw...
# 5  2023-05-02 18:10:00  Jl. Cihampelas No.50, Tamansari, Kec. Bandung ...
#
#    lat_jemput  long_jemput                                      lokasi_tujuan  \
# 0   -6.904833   107.647971                196b, Gg. Pabrik Kulit Selatan No.2
# 1   -6.901228   107.656385  Jl. Padasuka No.20, Pasirlayung, Kec. Cibeunyi...
# 3   -6.870245   107.593153  Jl. Jiwanaya No.02, RT.01/RW.04, Cibeunying, K...
# 4   -6.903948   107.652282  Jl. Puri Dago Mas Utara 1 No.33, Antapani Teng...
# 5   -6.902811   107.604631  Jl. Imam Bonjol No.47, Lebakgede, Kecamatan Co...
#
#    lat_tujuan  long_tujuan     datetime_selesai  jarak pendapatan_bersih  \
# 0   -6.939039   107.589858  2023-05-01 12:15:00   9.55             19200
# 1   -6.901107   107.653824  2023-05-01 11:48:00   0.37              7200
# 3   -6.879492   107.631440  2023-05-01 10:39:00   7.80             16000
# 4   -6.922764   107.665858  2023-05-01 09:17:00   3.90              8000
# 5   -6.890128   107.615151  2023-05-02 18:29:00   3.04              8800
#
#    poin_tambahan jenis_pembayaran  jarak_jemput_tujuan  perbedaan_jarak
# 0          150.0            Tunai                9.526            0.024
# 1          150.0            Tunai                0.339            0.031
# 3          150.0           Dompet                8.390            0.590
# 4          150.0           Dompet                3.817            0.083
# 5          150.0           Dompet                3.247            0.207

# %%
upper_1km = final_df[final_df['perbedaan_jarak']>1]
upper_1km.shape
# Out:
# (6935, 19)

# %%
upper_1km.to_excel('../data/upper_1km.xlsx', index=False)

# %% [markdown]
# Data upper_1km dicek pisah ulang berdasarkan titik yang berada di dalam cekungan bandung dan di luar cekungan bandung.

# %% [markdown]
# #### Load data setelah dipisah antara inside & outside cekungan

# %% [markdown]
# ##### Outside cekungan

# %%
# Load the Excel file into a pandas DataFrame
outside = pd.read_excel('../data/outside_cekungan_1.xlsx')
outside.head()
# Out:
#    OBJECTID     id       id_telp                       email    tanggal  \
# 0         1  13012  8.231775e+10  sandiabdilah1989@gmail.com 2023-05-02
# 1         3   2231  8.122401e+10   agusmulyadi123a@gmail.com        NaT
# 2         4   5655  8.212938e+10          dergojek@gmail.com        NaT
# 3         5   8823  8.822295e+10                         NaN        NaT
# 4         6  12555  8.122197e+10          bbebet23@gmail.com        NaT
#
#   jenis_pesanan      datetime_tugas  \
# 0          Ride 2023-05-02 06:32:00
# 1          Food 2023-05-02 18:31:00
# 2          Ride 2023-05-05 18:00:00
# 3          Ride 2023-05-10 10:17:00
# 4  Kurir Barang 2023-05-09 15:50:00
#
#                                        lokasi_jemput  lat_jemput  long_jemput  \
# 0           SDN Margaasih, Margaasih, Kec. Margaasih   -6.927080   107.264228
# 1  Jl. Phh. Mustofa No.14, RT.01/RW.15 Kel, Cikut...   -6.898062   107.073877
# 2                             Cijerah, Bandung Kulon   -6.609130   107.429335
# 3  Graha Kencana Residence Blok 2 No.35, Jl. Ibu ...   -6.738343   107.313234
# 4                       Jl Panjunan No. 30, Panjunan   -6.718176   108.564827
#
#                                        lokasi_tujuan  lat_tujuan  long_tujuan  \
# 0     Jl Melong Nyontrol No. 155, Melong, Cimahi Sel   -6.927080   107.264228
# 1  Jl. Tj. Sari Asri Residence No.71, Antapani We...   -6.906452   107.665916
# 2                         Jl Tirta Indah III No 307b   -6.908578   107.559577
# 3  SDN 1 Cibeber, Jl. Ibu Ganirah No.N. 71, Cibeb...   -6.891535   107.509246
# 4                  Jl Seskoau, Lembang, Kec. Lembang   -6.819647   107.619608
#
#      datetime_selesai  jarak  pendapatan_bersih  poin_tambahan  \
# 0 2023-05-02 06:52:00   1.75               8000            150
# 1 2023-05-02 19:03:00   4.33              10400            150
# 2 2023-05-05 18:18:00   2.52               8800            150
# 3 2023-05-10 10:26:00   1.13               8000            150
# 4 2023-05-09 16:45:00  17.53              34800            150
#
#   jenis_pembayaran  jarak_jemput_tujuan  perbedaan_jarak
# 0            Tunai                0.000            1.750
# 1           Dompet               86.070           81.740
# 2            Tunai               61.876           59.356
# 3            Tunai               40.498           39.368
# 4            Tunai              165.431          147.901

# %% [markdown]
# Geocoding

# %%
# Define your Google Maps Geocoding API key
api_key = "AIzaSyDr9hZlUP0gZrGE8anyl5eHHvrM-2W7zN4"
# Function to geocode an address within the Bandung area using Google Maps Geocoding API
def geocode_address(address):
    # convert address into string
    address = str(address)
    # Append ", Bandung" to the address to limit the geocoding to the Bandung area
    address += ", Bandung"
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={address}&key={api_key}"
    response = requests.get(url)
    data = response.json()
    if data['status'] == 'OK':
        lat = data['results'][0]['geometry']['location']['lat']
        lng = data['results'][0]['geometry']['location']['lng']
        return lat, lng
    else:
        return np.nan, np.nan

# %%
# Apply geocode_address only to the 'lokasi_jemput' column for the null rows
outside['lat_jemput'], outside['long_jemput'] = zip(*outside['lokasi_jemput'].apply(geocode_address))

# %%
outside.to_excel('../data/outside_geocode.xlsx', index=False)

# %%
outside.head()
# Out:
#    OBJECTID     id       id_telp                       email    tanggal  \
# 0         1  13012  8.231775e+10  sandiabdilah1989@gmail.com 2023-05-02
# 1         3   2231  8.122401e+10   agusmulyadi123a@gmail.com        NaT
# 2         4   5655  8.212938e+10          dergojek@gmail.com        NaT
# 3         5   8823  8.822295e+10                         NaN        NaT
# 4         6  12555  8.122197e+10          bbebet23@gmail.com        NaT
#
#   jenis_pesanan      datetime_tugas  \
# 0          Ride 2023-05-02 06:32:00
# 1          Food 2023-05-02 18:31:00
# 2          Ride 2023-05-05 18:00:00
# 3          Ride 2023-05-10 10:17:00
# 4  Kurir Barang 2023-05-09 15:50:00
#
#                                        lokasi_jemput  lat_jemput  long_jemput  \
# 0           SDN Margaasih, Margaasih, Kec. Margaasih   -6.933461   107.548397
# 1  Jl. Phh. Mustofa No.14, RT.01/RW.15 Kel, Cikut...   -6.897982   107.634699
# 2                             Cijerah, Bandung Kulon   -6.920836   107.566788
# 3  Graha Kencana Residence Blok 2 No.35, Jl. Ibu ...   -6.898261   107.523084
# 4                       Jl Panjunan No. 30, Panjunan   -6.930163   107.599090
#
#                                        lokasi_tujuan  lat_tujuan  long_tujuan  \
# 0     Jl Melong Nyontrol No. 155, Melong, Cimahi Sel   -6.927080   107.264228
# 1  Jl. Tj. Sari Asri Residence No.71, Antapani We...   -6.906452   107.665916
# 2                         Jl Tirta Indah III No 307b   -6.908578   107.559577
# 3  SDN 1 Cibeber, Jl. Ibu Ganirah No.N. 71, Cibeb...   -6.891535   107.509246
# 4                  Jl Seskoau, Lembang, Kec. Lembang   -6.819647   107.619608
#
#      datetime_selesai  jarak  pendapatan_bersih  poin_tambahan  \
# 0 2023-05-02 06:52:00   1.75               8000            150
# 1 2023-05-02 19:03:00   4.33              10400            150
# 2 2023-05-05 18:18:00   2.52               8800            150
# 3 2023-05-10 10:26:00   1.13               8000            150
# 4 2023-05-09 16:45:00  17.53              34800            150
#
#   jenis_pembayaran  jarak_jemput_tujuan  perbedaan_jarak
# 0            Tunai                0.000            1.750
# 1           Dompet               86.070           81.740
# 2            Tunai               61.876           59.356
# 3            Tunai               40.498           39.368
# 4            Tunai              165.431          147.901

# %%
from arcgis.gis import GIS

# Connect to your ArcGIS Online or ArcGIS Enterprise account
gis = GIS("https://www.arcgis.com", "studentitb22", "studentitb22k")

# Example: Create a new map
map_item = gis.map("New York, NY")
map_item.save({'title': 'My Map', 'tags': 'demo'})

print("Map URL:", map_item.url)
# Out:
# MapView class replaced with a non-functional placeholder due to the following import error:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 7
#       4 gis = GIS("https://www.arcgis.com", "studentitb22", "studentitb22k")
#       6 # Example: Create a new map
# ----> 7 map_item = gis.map("New York, NY")
#       8 map_item.save({'title': 'My Map', 'tags': 'demo'})
#      10 print("Map URL:", map_item.url)
#
# File ~/anaconda3/envs/suapp/lib/python3.11/site-packages/arcgis/gis/__init__.py:1325, in GIS.map(self, location, zoomlevel, mode, geocoder)
#    1323     mapwidget = MapView(gis=self, item=location, mode=mode)
#    1324 else:
# -> 1325     mapwidget = MapView(gis=self, mode=mode)
#    1327     # Geocode the location
#    1328     if isinstance(location, str):
#
# File ~/anaconda3/envs/suapp/lib/python3.11/site-packages/arcgis/widgets/__init__.py:15, in MapView.__init__(self, *args, **kwargs)
#      10 def __init__(self, *args, **kwargs):
#      11     log.warning(
#      12         "MapView class replaced with a non-functional "
#      13         "placeholder due to the following import error:"
#      14     )
# ---> 15     raise import_error
#
#     [... skipping hidden 1 frame]
#
# Cell In[11], line 7
#       4 gis = GIS("https://www.arcgis.com", "studentitb22", "studentitb22k")
#       6 # Example: Create a new map
# ----> 7 map_item = gis.map("New York, NY")
#       8 map_item.save({'title': 'My Map', 'tags': 'demo'})
#      10 print("Map URL:", map_item.url)
#
# File ~/anaconda3/envs/suapp/lib/python3.11/site-packages/arcgis/gis/__init__.py:1325, in GIS.map(self, location, zoomlevel, mode, geocoder)
#    1323     mapwidget = MapView(gis=self, item=location, mode=mode)
#    1324 else:
# -> 1325     mapwidget = MapView(gis=self, mode=mode)
#    1327     # Geocode the location
#    1328     if isinstance(location, str):
#
# File ~/anaconda3/envs/suapp/lib/python3.11/site-packages/arcgis/widgets/__init__.py:15, in MapView.__init__(self, *args, **kwargs)
#      10 def __init__(self, *args, **kwargs):
#      11     log.warning(
#      12         "MapView class replaced with a non-functional "
#      13         "placeholder due to the following import error:"
#      14     )
# ---> 15     raise import_error
#
#     [... skipping hidden 1 frame]
#
# Cell In[1], line 3
#       1 from arcgis.gis import GIS
#       2 my_gis = GIS()
# ----> 3 m = my_gis.map()
#       4 m
#
# File ~/anaconda3/envs/suapp/lib/python3.11/site-packages/arcgis/gis/__init__.py:1325, in GIS.map(self, location, zoomlevel, mode, geocoder)
#    1323     mapwidget = MapView(gis=self, item=location, mode=mode)
#    1324 else:
# -> 1325     mapwidget = MapView(gis=self, mode=mode)
#    1327     # Geocode the location
#    1328     if isinstance(location, str):
#
# File ~/anaconda3/envs/suapp/lib/python3.11/site-packages/arcgis/widgets/__init__.py:15, in MapView.__init__(self, *args, **kwargs)
#      10 def __init__(self, *args, **kwargs):
#      11     log.warning(
#      12         "MapView class replaced with a non-functional "
#      13         "placeholder due to the following import error:"
#      14     )
# ---> 15     raise import_error
#
# File ~/anaconda3/envs/suapp/lib/python3.11/site-packages/arcgis/widgets/__init__.py:2
#       1 try:
# ----> 2     from arcgis.widgets._mapview import MapView
#       3 except ImportError as e:
#       4     import logging
#
# File ~/anaconda3/envs/suapp/lib/python3.11/site-packages/arcgis/widgets/_mapview/__init__.py:1
# ----> 1 from arcgis.widgets._mapview._mapview import MapView
#
# File ~/anaconda3/envs/suapp/lib/python3.11/site-packages/arcgis/widgets/_mapview/_mapview.py:31
#      29 from arcgis.widgets._mapview._webscene_utils import DEFAULT_WEBSCENE_TEXT_PROPERTY
#      30 from arcgis.widgets._mapview._loading_icon_str import _loading_icon_str
# ---> 31 from arcgis.widgets._mapview._raster import LocalRasterOverlayManager
#      32 from arcgis.widgets._mapview._raster._numpy_utils import *
#      33 from arcgis import __version__ as py_api_version
#
# File ~/anaconda3/envs/suapp/lib/python3.11/site-packages/arcgis/widgets/_mapview/_raster/__init__.py:1
# ----> 1 from arcgis.widgets._mapview._raster.local_raster_overlay_manager import (
#       2     LocalRasterOverlayManager,
#       3     RasterOverlay,
#       4 )
#
# File ~/anaconda3/envs/suapp/lib/python3.11/site-packages/arcgis/widgets/_mapview/_raster/local_raster_overlay_manager.py:7
#       5 from arcgis.widgets._mapview._raster import *
#       6 from arcgis.widgets._mapview._raster._numpy_utils import *
# ----> 7 from arcgis.widgets._mapview._raster._jupyter_utils import *
#      10 class RasterOverlay:
#      11     def __init__(self, id_: str, img_url: str, extent: dict, opacity: float):
#
# File ~/anaconda3/envs/suapp/lib/python3.11/site-packages/arcgis/widgets/_mapview/_raster/_jupyter_utils.py:10
#       7 log = logging.getLogger()
#       9 import ipykernel
# ---> 10 from notebook.notebookapp import list_running_servers
#      11 from IPython.display import HTML, display
#      14 def get_dir_of_curr_exec_notebook():
#
# ModuleNotFoundError: No module named 'notebook'
